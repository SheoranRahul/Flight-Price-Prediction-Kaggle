# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('~/Downloads/HousePrices.csv')

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.isnull().sum().tail(40)
# Out:
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.drop('PoolQC',axis=1,inplace=True)

# %%
df['GarageType'].fillna('NO',inplace=True)

# %%
df.drop('MiscFeature',axis=1,inplace=True)

# %%
df.drop('Alley',axis=1,inplace=True)

# %%
df['Fence']=df['Fence'].fillna('No')

# %%
df['Fence'].replace({'MnPrv':'Yes','GdWo':'Yes','GdPrv':'Yes','MnWw':'Yes'},inplace=True)

# %%
df['Fence'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['FireplaceQu']=df['FireplaceQu'].fillna('No')

# %%
df['FireplaceQu'].replace({'Gd':'Good','Ex':'Good','TA':'Avg','Fa':'Avg','Po':'No'},inplace=True)

# %%
df['FireplaceQu'].unique()
# Out:
# array(['No', 'Avg', 'Good'], dtype=object)

# %%
df['LotFrontage']=df['LotFrontage'].fillna(70)
df['Electrical']=df['Electrical'].fillna('SBrkr')

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix'], dtype=object)

# %%
df['Electrical'].replace({'FuseA':'Others','FuseF':'Others','FuseP':'Others','Mix':'Others'},inplace=True)

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'Others'], dtype=object)

# %%
df['GarageFinish']=df['GarageFinish'].fillna('No')

# %%
df['MasVnrArea']=df['MasVnrArea'].fillna(0)

# %%
df['MasVnrType']=df['MasVnrType'].fillna('No')

# %%
df['BsmtQual']=df['BsmtQual'].fillna('No')

# %%
df['BsmtCond']=df['BsmtCond'].fillna('No')

# %%
df['BsmtExposure']=df['BsmtExposure'].fillna('No')

# %%
df['BsmtFinType1']=df['BsmtFinType1'].fillna('No')

# %%
df['BsmtFinType2']=df['BsmtFinType2'].fillna('No')

# %%
df['GarageQual']=df['GarageQual'].fillna('No')

# %%
df['GarageCond']=df['GarageCond'].fillna('No')

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# GarageYrBlt     81
# BedroomAbvGr     0
# GarageType       0
# FireplaceQu      0
# Fireplaces       0
# Functional       0
# TotRmsAbvGrd     0
# KitchenQual      0
# KitchenAbvGr     0
# MSSubClass       0
# CentralAir       0
# FullBath         0
# BsmtHalfBath     0
# BsmtFullBath     0
# GrLivArea        0
# LowQualFinSF     0
# 2ndFlrSF         0
# 1stFlrSF         0
# HalfBath         0
# GarageFinish     0
# dtype: int64

# %%
df.drop('GarageYrBlt',axis=1,inplace=True)

# %%
import statsmodels
import statsmodels.api as sm

# %%
X=df.drop('SalePrice',axis=1)

# %%
y=df['SalePrice']

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X=sm.add_constant(X)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model=sm.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     71.60
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:42:43   Log-Likelihood:                -16590.
# No. Observations:                1460   AIC:                         3.365e+04
# Df Residuals:                    1227   BIC:                         3.488e+04
# Df Model:                         232
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
df.drop(['MSSubClass','LotFrontage','BsmtFinSF2','LowQualFinSF','BsmtFullBath','BsmtHalfBath','HalfBath','OpenPorchSF','EnclosedPorch','MiscVal'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1460, 66)

# %%
X=df.drop('SalePrice',axis=1)

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X['const']=1

# %%
y=df['SalePrice']

# %%
model2=sm.OLS(y,X).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     74.42
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):               0.00
# Time:                        13:55:29   Log-Likelihood:                -16592.
# No. Observations:                1460   AIC:                         3.363e+04
# Df Residuals:                    1235   BIC:                         3.482e+04
# Df Model:                         224
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=12,test_size=0.2)

# %%
model3=sm.OLS(y_train,X_train).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     70.77
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):               0.00
# Time:                        14:00:01   Log-Likelihood:                -13173.
# No. Observations:                1168   AIC:                         2.678e+04
# Df Residuals:                     949   BIC:                         2.789e+04
# Df Model:                         218
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
df.drop(['SaleCondition','SaleType','Fence','PavedDrive','GarageFinish','FireplaceQu','Functional','Electrical','CentralAir','Heating','BsmtFinType2','BsmtFinType1','BsmtCond','Foundation','ExterCond','MasVnrType'],axis=1,inplace=True)

# %%
y_train_predicted=model3.predict(X_train)

# %%
RMSE_Train=np.sqrt(np.sum((y_train-y_train_predicted)**2)/len(y_train))

# %%
RMSE_Train
# Out:
# 19131.396736888088

# %%
y_test_predicted=model3.predict(X_test)

# %%
RMSE_Test=np.sqrt(np.sum((y_test-y_test_predicted)**2)/len(y_test))

# %%
RMSE_Test
# Out:
# 36088.7343763435

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df.shape
# Out:
# (1460, 50)

# %%
X=df.drop('SalePrice',axis=1)

# %%
y=df['SalePrice']

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X['const']=1

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=10,test_size=0.2)

# %%
X_test.shape,X_train.shape
# Out:
# ((292, 168), (1168, 168))

# %%
model4=sm.OLS(y_train,X_train).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     80.42
# Date:                Fri, 05 Aug 2022   Prob (F-statistic):               0.00
# Time:                        14:32:35   Log-Likelihood:                -13301.
# No. Observations:                1168   AIC:                         2.692e+04
# Df Residuals:                    1007   BIC:                         2.774e+04
# Df Model:                         160
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
y_train_predicted=model4.predict(X_train)

# %%
RMSE_Train=np.sqrt(np.sum((y_train-y_train_predicted)**2)/len(y_train))

# %%
RMSE_Train
# Out:
# 21354.988201347034

# %%
y_test_predicted=model4.predict(X_test)

# %%
RMSE_Test=np.sqrt(np.sum((y_test-y_test_predicted)**2)/len(y_test))

# %%
RMSE_Test
# Out:
# 62941.29558606501
